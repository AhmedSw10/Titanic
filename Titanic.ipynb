# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedSw10/Titanic/blob/main/Titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic =sns.load_dataset('titanic')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.describe(include='all')
# Out:
#           survived      pclass   sex         age       sibsp       parch  \
# count   891.000000  891.000000   891  714.000000  891.000000  891.000000
# unique         NaN         NaN     2         NaN         NaN         NaN
# top            NaN         NaN  male         NaN         NaN         NaN
# freq           NaN         NaN   577         NaN         NaN         NaN
# mean      0.383838    2.308642   NaN   29.699118    0.523008    0.381594
# std       0.486592    0.836071   NaN   14.526497    1.102743    0.806057
# min       0.000000    1.000000   NaN    0.420000    0.000000    0.000000
# 25%       0.000000    2.000000   NaN   20.125000    0.000000    0.000000
# 50%       0.000000    3.000000   NaN   28.000000    0.000000    0.000000
# 75%       1.000000    3.000000   NaN   38.000000    1.000000    0.000000
# max       1.000000    3.000000   NaN   80.000000    8.000000    6.000000
#
#               fare embarked  class  who adult_male deck  embark_town alive  \
# ...

# %%
#check null vlues

print(titanic.isnull().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic['age'].fillna( titanic['age'].median(), inplace = True)
# Out:
# <ipython-input-192-2295848815>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['age'].fillna( titanic['age'].median(), inplace = True)

# %%
print(titanic.isnull().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic['embark_town'].fillna( titanic['embark_town'].mode()[0], inplace = True)
# Out:
# <ipython-input-194-4176011631>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['embark_town'].fillna( titanic['embark_town'].mode()[0], inplace = True)

# %%
print(titanic.isnull().sum())
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      0
# alive            0
# alone            0
# dtype: int64

# %%
titanic.drop(columns=['deck'], inplace=True)

# %%
print(titanic.isnull().sum())
# Out:
# survived       0
# pclass         0
# sex            0
# age            0
# sibsp          0
# parch          0
# fare           0
# embarked       2
# class          0
# who            0
# adult_male     0
# embark_town    0
# alive          0
# alone          0
# dtype: int64

# %%
top10=titanic.nlargest(10,'fare')

# %%
print(top10)
# Out:
#      survived  pclass     sex   age  sibsp  parch      fare embarked  class  \
# 258         1       1  female  35.0      0      0  512.3292        C  First
# 679         1       1    male  36.0      0      1  512.3292        C  First
# 737         1       1    male  35.0      0      0  512.3292        C  First
# 27          0       1    male  19.0      3      2  263.0000        S  First
# 88          1       1  female  23.0      3      2  263.0000        S  First
# 341         1       1  female  24.0      3      2  263.0000        S  First
# 438         0       1    male  64.0      1      4  263.0000        S  First
# 311         1       1  female  18.0      2      2  262.3750        C  First
# 742         1       1  female  21.0      2      2  262.3750        C  First
# 118         0       1    male  24.0      0      1  247.5208        C  First
#
#        who  adult_male  embark_town alive  alone
# 258  woman       False    Cherbourg   yes   True
# ...

# %%
# @title duplicated Value
dup=titanic.value_counts()
duplicated=dup[dup>1]
print(duplicated)
# Out:
# survived  pclass  sex     age    sibsp  parch  fare     embarked  class   who    adult_male  embark_town  alive  alone
# 0         3       male    28.00  0      0      7.8958   S         Third   man    True        Southampton  no     True     15
#                                                8.0500   S         Third   man    True        Southampton  no     True     12
#                                                7.7500   Q         Third   man    True        Queenstown   no     True      9
# 1         3       female  28.00  0      0      7.7500   Q         Third   woman  False       Queenstown   yes    True      7
# 0         2       male    28.00  0      0      0.0000   S         Second  man    True        Southampton  no     True      6
#           3       male    28.00  0      0      7.2292   C         Third   man    True        Cherbourg    no     True      5
# ...

# %%
print(titanic.duplicated().sum())
# Out:
# 116

# %%
titanic.drop_duplicates(inplace=True) # Remove_Duplicate

# %%
print(titanic.duplicated().sum())
# Out:
# 0

# %%
# @title Exploratory Data Analysis

# %%
#Distribution of passanger age

plt.figure(figsize=(8,5))
sns.distplot(titanic['age'] , bins=30 , kde=True)
plt.title('Distribution of Passanger Age')
plt.xlabel=("Age")
plt.ylabel("Frequency")
plt.show()
# Out:
# <ipython-input-205-4101071440>:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic['age'] , bins=30 , kde=True)

# %%
plt.figure(figsize=(50,20))
sns.countplot(x='age',hue='survived' , data=titanic)
plt.title('survived as per Age')
plt.xlabel=("Age")
plt.ylabel("Frequency")
plt.show()
plt.close()

# %%
plt.figure(figsize=(30,10))
sns.countplot(x='sex',hue='survived' , data=titanic)
plt.title('survived as per sex')
plt.xlabel=("sex")
plt.ylabel("Frequency")
plt.show()
plt.close()

# %%
# The Ratio Of Living Men To Dead men.
male_titanic = titanic[titanic['sex'] == 'male']
plt.figure(figsize=(30,10))
sns.countplot(x='age',hue='survived' , data=male_titanic)
plt.title('survived as per SEX')
plt.xlabel=("sex")
plt.ylabel("Frequency")
plt.show()
plt.close()

# %%
male_titanic = titanic[titanic['sex'] == 'male']
plt.figure(figsize=(30,10))
sns.barplot(x='age', y='survived', data=male_titanic)
plt.title('survived as men')
plt.xlabel=("sex")
plt.ylabel("Frequency")
plt.show()
plt.close()

# %%
# alive as per class
male_titanic = titanic[titanic['sex'] == 'male']
plt.figure(figsize=(30,10))
sns.barplot(x='class', y='survived', data=titanic)
plt.title('survived as men')
plt.xlabel=("sex")
plt.ylabel("Frequency")
plt.show()
plt.close()

# %%
titanic['family_size'] = titanic['sibsp'] + titanic['parch'] + 1
titanic['is_alone'] = np.where(titanic['family_size']> 1,'not alone','alone')

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone  family_size   is_alone
# 0    man        True  Southampton    no  False            2  not alone
# 1  woman       False    Cherbourg   yes  False            2  not alone
# 2  woman       False  Southampton   yes   True            1      alone
# 3  woman       False  Southampton   yes  False            2  not alone
# 4    man        True  Southampton    no   True            1      alone

# %%
plt.figure(figsize=(8,5))
sns.barplot(x='family_size', y='survived', data=titanic)
plt.title('survived with Family')
plt.xlabel=("family_size")
plt.ylabel("Frequency")
plt.show()
plt.close()

# %%
titanic['total_pass'] = titanic.groupby('embark_town').size()

# %%
titanic['family_size'] = titanic['sibsp'] + titanic['parch'] + 1

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male  embark_town alive  alone  family_size   is_alone  \
# 0    man        True  Southampton    no  False            2  not alone
# 1  woman       False    Cherbourg   yes  False            2  not alone
# 2  woman       False  Southampton   yes   True            1      alone
# 3  woman       False  Southampton   yes  False            2  not alone
# 4    man        True  Southampton    no   True            1      alone
#
#    total_pass
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
totalpass = titanic['embark_town'].value_counts()
print(totalpass)
# Out:
# embark_town
# Southampton    562
# Cherbourg      155
# Queenstown      58
# Name: count, dtype: int64

# %%
type(totalpass)
# Out:
# pandas.core.series.Series

# %%
totalpass = titanic['embark_town'].value_counts()
totalalivpass = titanic[titanic['survived']== 0]['embark_town'].value_counts()
print(totalalivpass)
# Out:
# embark_town
# Southampton    352
# Cherbourg       65
# Queenstown      38
# Name: count, dtype: int64

# %%
titanic['total_pass']=titanic['embark_town'].map(totalpass)
titanic['total_alive_pass']=titanic['embark_town'].map(totalalivpass)

# %%
plt.figure(figsize=(30,10))
sns.countplot(x='embark_town',hue='survived' , data=titanic)
plt.title('survived as per city')
plt.xlabel=("city")
plt.ylabel("Frequency")
plt.show()
plt.close()

# %% [markdown]
# **ML**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler ,MinMaxScaler,OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer

# %%
x=titanic.drop(columns=['survived'])
y=titanic['survived']
x_train,x_test,y_train,y_test=train_test_split(x,y,stratify=y,test_size=0.2,random_state=42)

# %%
Numerical_pipline=Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='median')),
    ('scaler',MinMaxScaler())
])

Categorical_pipline=Pipeline(steps=[
    ('imputer',SimpleImputer(strategy='most_frequent')),
    ('Encoding',OneHotEncoder(drop='first',handle_unknown='ignore'))
])

# %%
Num_col=x.select_dtypes(include=['int64','float64']).columns
Cat_col=x.select_dtypes(include=['object']).columns

# %%
preprocessing=ColumnTransformer(transformers=[
    ('Numerical_preprocessing',Numerical_pipline,Num_col),
    ('Categorical_preprocessing',Categorical_pipline,Cat_col)
])

# %%
model=Pipeline(steps=[
        ('preprocessing',preprocessing),
         ('modeling',LogisticRegression())
         ])
model
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('Numerical_preprocessing',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   Index(['pclass', 'age', 'sibsp', 'parch', 'fare', 'family_size', 'total_pass',
#        'total_alive_pass'],
#       dtype='object')),
#                                                  ('Categorical_preprocessing',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
# ...

# %%
model.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('Numerical_preprocessing',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   Index(['pclass', 'age', 'sibsp', 'parch', 'fare', 'family_size', 'total_pass',
#        'total_alive_pass'],
#       dtype='object')),
#                                                  ('Categorical_preprocessing',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
# ...

# %%
predict=model.predict(x_train)
confusion_matrix(y_train,predict)
# Out:
# array([[364,   0],
#        [  0, 256]])

# %%
predict=model.predict(x_test)
confusion_matrix(y_test,predict)
# Out:
# array([[91,  0],
#        [ 0, 64]])

# %%
print(classification_report(y_test,predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        91
#            1       1.00      1.00      1.00        64
#
#     accuracy                           1.00       155
#    macro avg       1.00      1.00      1.00       155
# weighted avg       1.00      1.00      1.00       155

# %% [markdown]
# 🔍 ***Insights Analysis ***
#
# **Age Distribution**
#
# The majority of passengers were young adults, though a considerable number of children and elderly individuals were also present. This diverse age distribution influenced survival rates, especially among the most vulnerable age groups.
#
#
# **Gender and Survival**
#
# Women exhibited significantly higher survival rates compared to men, aligning with the maritime principle of "women and children first." This policy had a clear impact on the overall demographics of survivors.
#
# **Passenger Class and Survival**
#
# Survival rates were notably higher among first-class passengers than those in second or third class. This highlights a clear class-based disparity, likely influenced by cabin location, access to lifeboats, and prioritization during evacuation.
#
# **Family Size and Survival**
#
# Passengers traveling with small to moderate family sizes had better chances of survival, possibly due to increased mutual support. In contrast, individuals traveling alone had the lowest survival rates, suggesting isolation reduced their chances of receiving timely assistance.
#
# **Embarkation Town and Survival**
# Survival rates varied depending on the town of embarkation, potentially reflecting differing socioeconomic statuses and passenger profiles. Notably, Cherbourg stood out as the embarkation point with the highest number of survivors. As a coastal city, Cherbourg may have attracted wealthier passengers who secured first-class accommodations, thereby increasing their likelihood of survival.
